# %% [markdown]
# # Neural network using torch

# %% [markdown]
# ## Importing required libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

# %% [markdown]
# ## Training settings

# %%
batch_size = 64

# %% [markdown]
# ## Getting MNIST dataset

# %%
train_dataset = datasets.MNIST(root='./mnist_data/',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='./mnist_data/',
                              train=False,
                              transform=transforms.ToTensor())

# %% [markdown]
# ## Data Loader (Input Pipeline)

# %%
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False)

# %% [markdown]
# ## 1-Setting neural network model

# %%
class Net(nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.l1 = nn.Linear(784, 520) # input x is 784 so we start from here
        self.l2 = nn.Linear(520, 320)
        self.l3 = nn.Linear(320, 240)
        self.l4 = nn.Linear(240, 120)
        self.l5 = nn.Linear(120, 10) # ouput is of ten categories in number. So we end it with 10

    def forward(self, x):
        x = x.view(-1, 784)  # Flatten the data (n, 1, 28, 28)-> (n, 784)
# 28*28 is 784. So, we divide equally. 1 represent color
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))
        x = F.relu(self.l3(x))
        x = F.relu(self.l4(x))
        return self.l5(x)

# %%
model = Net()

# %% [markdown]
# ## 2-Construct loss and optimizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %% [markdown]
# ## 3-Training Cycle
#  - Forward
#  - backward
#  - update

# %%
def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %% [markdown]
# ## 4- Testing the model

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).item()
        # get the index of the max
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
#Full range of train and test set where we can see how loss function of our prediction has changed
for epoch in range(1, 10):
    train(epoch)
    test()
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.305357
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.303264
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.305445
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.292897
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.290575
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.296599
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.305997
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.294274
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.298459
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.298113
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.297287
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 2.300120
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 2.305649
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 2.298032
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.297963
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 2.301248
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 2.309659
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 2.296517
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 2.296406
# ...

# %% [markdown]
# **At final setp, we manage to have a 96% accuracy and 0.0017 average loss shown from our test set**
